# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# #### **Jalvo Alef**

# %% [markdown]
# *Computer Data Engineer*

# %% [markdown]
# #### Using matplotlib.pyplot create a scatter plot showing the relationship between Stock Price (x axis) and Bond Yield (y axis) for the ten periods.

# %%
import matplotlib.pyplot as plt

x=[96,98,99,103,105,110,111,113,115,116]
y=[3.0,3.1,3.1,3.3,3.4,3.6,3.6,3.7,3.8,4.0]

plt.scatter(x,y)
plt.xlabel('Stock Price')
plt.ylabel('Bond Yield')
plt.show()

# %% [markdown]
# * one
# * two
# * three
# * one
# * two
# * three

# %% [markdown]
# Markdown | Less | Pretty
# --- | --- | ---
# *Still* | `renders` | **pretty**
# 1 | 2 | 3

# %% [markdown]
# ![alt text][logo]
#
# [logo]: https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/FinalModule_Coursera/images/SN_web_lightmode.png "Logo Title Text 2"

# %% [markdown]
# [My linkedin address](https://www.linkedin.com/in/jalvo-alef/)
